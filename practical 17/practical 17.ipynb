# %%
import pandas as pd
import numpy as np

# STEP 1: Create Dirty Dataset
df = pd.read_csv("raw_data.csv")

print("--- Step 1: Raw Data ---")
print(df)

# STEP 2: Remove Duplicates
df = df.drop_duplicates()

print("\n--- Step 2: Duplicates Removed ---")
print(df)

# STEP 3: Handle Missing Values
df['Name'] = df['Name'].fillna('Unknown')

# Fill Age with mean
mean_age = df['Age'].mean()
df['Age'] = df['Age'].fillna(mean_age)

# STEP 4: Data Type Transformation
df['Salary'] = pd.to_numeric(df['Salary'], errors='coerce')

# Fill missing salary with median
median_salary = df['Salary'].median()
df['Salary'] = df['Salary'].fillna(median_salary)

# STEP 5: Fix Outliers & Standardize Text
# Replace Age > 100 with average (30 for simplicity)
df.loc[df['Age'] > 100, 'Age'] = 30

# Capitalize names
df['Name'] = df['Name'].str.title()

# STEP 6: Normalize Date Format
df['Join_Date'] = pd.to_datetime(df['Join_Date'], errors='coerce')

print("\n--- Step 6: Final Cleaned Data ---")
print(df)

# OPTIONAL: Save cleaned data
df.to_csv("cleaned_employee_data.csv", index=False)

print("\nCleaned dataset saved as 'cleaned_employee_data.csv'")
# Out:
# --- Step 1: Raw Data ---
#     Employee_ID        Name    Age   Salary   Join_Date
# 0           101  anil kumar   28.0    50000  2023-01-10
# 1           102      Sunita   32.0    60000  2023/05/12
# 2           103         NaN  150.0    75000  12-08-2023
# 3           101  anil kumar   28.0    50000  2023-01-10
# 4           105       Rahul    NaN  missing  2023-09-01
# 5           106        amit   45.0    45000  15/07/2023
# 6           107        Neha   29.0    52000  2023-02-14
# 7           108      Vikram   40.0    78000  2023/06/18
# 8           109      Suresh   35.0    -1000  05-09-2023
# 9           110       pooja   24.0    48000  2022/12/01
# 10          111       Karan   31.0    65000  10/10/2023
# 11          112         NaN   27.0  missing  2023-11-20
# 12          113       Sneha  200.0    85000  21/04/2023
# 13          114      Ramesh   38.0    62000  2023-03-30
# 14          115      Ramesh   38.0    62000  2023-03-30
# 15          116        Gita   25.0   999999  2023/08/11
# 16          117       Nitin    NaN    41000  31-01-2023
# 17          118       vijay   42.0       na  2023-07-22
# 18          119       Manoj   34.0    51000  02/09/2023
# 19          120      Anjali   16.0    10000  2023-10-15
# 20          121       Priya   55.0    71000  2023/11/05
# 21          122       Rohit   30.0      NaN  04-06-2023
# 22          123      Kavita  140.0    49000  2023-12-12
# 23          124  ravi kumar   29.0    55000  19/02/2023
# 24          125       sonia   36.0    -5000  2023-04-28
# 25          126        Arun   33.0    63000  20-03-2023
# 26          127         NaN   26.0    50000  2023/05/21
# 27          128      Sanjay   -5.0    80000  13/08/2023
# 28          129     prakash   48.0      NaN  2023-01-25
# 29          130       Kiran   22.0    46000  17-09-2023
# 30          131       Tarun   37.0    68000  2023/02/28
# 31          129     prakash   48.0      NaN  2023-01-25
# 32          133        Ritu   28.0    52000  25/12/2022
# 33          134        Ajay    NaN  missing  2023-06-30
# 34          135       Megha   31.0    58000           -
# 35          136      Lokesh   41.0    74000  2023/07/07
# 36          137       deepa   24.0  1000000  08-11-2023
# 37          138      Naveen   39.0      NaN  2023-05-16
# 38          139       Swati   27.0    51000  22/01/2023
# 39          140         NaN   30.0    55000  2023-10-02
# 40          141       Ashok  300.0    61000  14/04/2023
# 41          142       Rekha   35.0    45000  2023-09-18
# 42          143      Rakesh   44.0    -2000  03-05-2023
# 43          144      Bhavna   23.0      NaN  2023/08/29
# 44          145      Harish   29.0    54000  27-02-2023
# 45          145      Harish   29.0    54000  27-02-2023
# 46          147       Jyoti    NaN    66000  2023-12-05
# 47          148      Dinesh   50.0    81000  11/06/2023
# 48          149        Asha   32.0    49000  30-07-2023
# 49          150      manish  -10.0  missing  2023/11/14
#
# --- Step 2: Duplicates Removed ---
#     Employee_ID        Name    Age   Salary   Join_Date
# 0           101  anil kumar   28.0    50000  2023-01-10
# 1           102      Sunita   32.0    60000  2023/05/12
# 2           103         NaN  150.0    75000  12-08-2023
# 4           105       Rahul    NaN  missing  2023-09-01
# 5           106        amit   45.0    45000  15/07/2023
# 6           107        Neha   29.0    52000  2023-02-14
# 7           108      Vikram   40.0    78000  2023/06/18
# 8           109      Suresh   35.0    -1000  05-09-2023
# 9           110       pooja   24.0    48000  2022/12/01
# 10          111       Karan   31.0    65000  10/10/2023
# 11          112         NaN   27.0  missing  2023-11-20
# 12          113       Sneha  200.0    85000  21/04/2023
# 13          114      Ramesh   38.0    62000  2023-03-30
# 14          115      Ramesh   38.0    62000  2023-03-30
# 15          116        Gita   25.0   999999  2023/08/11
# 16          117       Nitin    NaN    41000  31-01-2023
# 17          118       vijay   42.0       na  2023-07-22
# 18          119       Manoj   34.0    51000  02/09/2023
# 19          120      Anjali   16.0    10000  2023-10-15
# 20          121       Priya   55.0    71000  2023/11/05
# 21          122       Rohit   30.0      NaN  04-06-2023
# 22          123      Kavita  140.0    49000  2023-12-12
# 23          124  ravi kumar   29.0    55000  19/02/2023
# 24          125       sonia   36.0    -5000  2023-04-28
# 25          126        Arun   33.0    63000  20-03-2023
# 26          127         NaN   26.0    50000  2023/05/21
# 27          128      Sanjay   -5.0    80000  13/08/2023
# 28          129     prakash   48.0      NaN  2023-01-25
# 29          130       Kiran   22.0    46000  17-09-2023
# 30          131       Tarun   37.0    68000  2023/02/28
# 32          133        Ritu   28.0    52000  25/12/2022
# 33          134        Ajay    NaN  missing  2023-06-30
# 34          135       Megha   31.0    58000           -
# 35          136      Lokesh   41.0    74000  2023/07/07
# 36          137       deepa   24.0  1000000  08-11-2023
# 37          138      Naveen   39.0      NaN  2023-05-16
# 38          139       Swati   27.0    51000  22/01/2023
# 39          140         NaN   30.0    55000  2023-10-02
# 40          141       Ashok  300.0    61000  14/04/2023
# 41          142       Rekha   35.0    45000  2023-09-18
# 42          143      Rakesh   44.0    -2000  03-05-2023
# 43          144      Bhavna   23.0      NaN  2023/08/29
# 44          145      Harish   29.0    54000  27-02-2023
# 46          147       Jyoti    NaN    66000  2023-12-05
# 47          148      Dinesh   50.0    81000  11/06/2023
# 48          149        Asha   32.0    49000  30-07-2023
# 49          150      manish  -10.0  missing  2023/11/14
#
# --- Step 6: Final Cleaned Data ---
#     Employee_ID        Name        Age     Salary  Join_Date
# 0           101  Anil Kumar  28.000000    50000.0 2023-01-10
# 1           102      Sunita  32.000000    60000.0        NaT
# 2           103     Unknown  30.000000    75000.0        NaT
# 4           105       Rahul  46.697674    55000.0 2023-09-01
# 5           106        Amit  45.000000    45000.0        NaT
# 6           107        Neha  29.000000    52000.0 2023-02-14
# 7           108      Vikram  40.000000    78000.0        NaT
# 8           109      Suresh  35.000000    -1000.0        NaT
# 9           110       Pooja  24.000000    48000.0        NaT
# 10          111       Karan  31.000000    65000.0        NaT
# 11          112     Unknown  27.000000    55000.0 2023-11-20
# 12          113       Sneha  30.000000    85000.0        NaT
# 13          114      Ramesh  38.000000    62000.0 2023-03-30
# 14          115      Ramesh  38.000000    62000.0 2023-03-30
# 15          116        Gita  25.000000   999999.0        NaT
# 16          117       Nitin  46.697674    41000.0        NaT
# 17          118       Vijay  42.000000    55000.0 2023-07-22
# 18          119       Manoj  34.000000    51000.0        NaT
# 19          120      Anjali  16.000000    10000.0 2023-10-15
# 20          121       Priya  55.000000    71000.0        NaT
# 21          122       Rohit  30.000000    55000.0        NaT
# 22          123      Kavita  30.000000    49000.0 2023-12-12
# 23          124  Ravi Kumar  29.000000    55000.0        NaT
# 24          125       Sonia  36.000000    -5000.0 2023-04-28
# 25          126        Arun  33.000000    63000.0        NaT
# 26          127     Unknown  26.000000    50000.0        NaT
# 27          128      Sanjay  -5.000000    80000.0        NaT
# 28          129     Prakash  48.000000    55000.0 2023-01-25
# 29          130       Kiran  22.000000    46000.0        NaT
# 30          131       Tarun  37.000000    68000.0        NaT
# 32          133        Ritu  28.000000    52000.0        NaT
# 33          134        Ajay  46.697674    55000.0 2023-06-30
# 34          135       Megha  31.000000    58000.0        NaT
# 35          136      Lokesh  41.000000    74000.0        NaT
# 36          137       Deepa  24.000000  1000000.0        NaT
# 37          138      Naveen  39.000000    55000.0 2023-05-16
# 38          139       Swati  27.000000    51000.0        NaT
# 39          140     Unknown  30.000000    55000.0 2023-10-02
# 40          141       Ashok  30.000000    61000.0        NaT
# 41          142       Rekha  35.000000    45000.0 2023-09-18
# 42          143      Rakesh  44.000000    -2000.0        NaT
# 43          144      Bhavna  23.000000    55000.0        NaT
# 44          145      Harish  29.000000    54000.0        NaT
# 46          147       Jyoti  46.697674    66000.0 2023-12-05
# 47          148      Dinesh  50.000000    81000.0        NaT
# 48          149        Asha  32.000000    49000.0        NaT
# 49          150      Manish -10.000000    55000.0        NaT
#
# Cleaned dataset saved as 'cleaned_employee_data.csv'
