# %%
import pandas as pd

# Step 1: Load the dataset
data = pd.read_csv("Sales_Dataset_2025.csv")

# %%
import pandas as pd

# Step 1: Load the dataset
data = pd.read_csv("Sales_Dataset_2025.csv")

# Step 2: Display basic information
print("----- BASIC INFORMATION -----")
print("Number of Rows:", data.shape[0])
print("Number of Columns:", data.shape[1])
print("\nColumn Data Types:\n")
print(data.dtypes)

# Step 3: Categorize based on Organization
print("\n----- ORGANIZATION TYPE -----")
if isinstance(data, pd.DataFrame):
    print("The dataset is Structured Data (Rows and Columns format).")

# Step 4: Categorize based on Format
print("\n----- FORMAT TYPE -----")
print("The dataset is in CSV (Comma Separated Values) format.")

# Step 5: Categorize based on Structure (Quantitative & Qualitative)

quantitative = data.select_dtypes(include=['int64', 'float64']).columns
qualitative = data.select_dtypes(include=['object']).columns

print("\n----- STRUCTURE TYPE -----")
print("Quantitative Columns:")
print(list(quantitative))

print("\nQualitative Columns:")
print(list(qualitative))

# Step 6: Analytical Suitability
print("\n----- ANALYTICAL SUITABILITY -----")
print("✔ Suitable for Descriptive Analysis")
print("✔ Suitable for Trend Analysis")
print("✔ Suitable for Statistical Modeling")
print("✔ Suitable for Predictive Analytics")
# Out:
# ----- BASIC INFORMATION -----
# Number of Rows: 24
# Number of Columns: 5
#
# Column Data Types:
#
# Month                object
# Region               object
# Sales                 int64
# Advertising_Spend     int64
# Profit                int64
# dtype: object
#
# ----- ORGANIZATION TYPE -----
# The dataset is Structured Data (Rows and Columns format).
#
# ----- FORMAT TYPE -----
# The dataset is in CSV (Comma Separated Values) format.
#
# ----- STRUCTURE TYPE -----
# Quantitative Columns:
# ['Sales', 'Advertising_Spend', 'Profit']
#
# Qualitative Columns:
# ['Month', 'Region']
#
# ----- ANALYTICAL SUITABILITY -----
# ✔ Suitable for Descriptive Analysis
# ✔ Suitable for Trend Analysis
# ✔ Suitable for Statistical Modeling
# ✔ Suitable for Predictive Analytics
