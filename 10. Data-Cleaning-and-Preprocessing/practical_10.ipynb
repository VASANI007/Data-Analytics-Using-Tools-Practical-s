# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from IPython.display import HTML

# %%
data = pd.read_csv("employee_data.csv")
data.head()

html_table = data.to_html(index=False, justify='center')

display(HTML(html_table))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: center;">
#       <th>ID</th>
#       <th>Name</th>
#       <th>Age</th>
#       <th>Salary</th>
#       <th>Join_Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>Rahul</td>
#       <td>25</td>
#       <td>30000</td>
#       <td>01-02-2023</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>Anita</td>
#       <td>27</td>
#       <td>35000</td>
#       <td>12-03-2023</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>Karan</td>
#       <td>24</td>
#       <td>28000</td>
#       <td>20-01-2023</td>
#     </tr>
#   </tbody>
# </table>

# %%
data["Join_Date"] = pd.to_datetime(data["Join_Date"])

# %%
data["Name"] = data["Name"].astype(str)

# %%
scaler = StandardScaler()
data["Salary_Scaled"] = scaler.fit_transform(data[["Salary"]])

# %%
data.head()
html_table = data.to_html(index=False, justify='center')

display(HTML(html_table))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: center;">
#       <th>ID</th>
#       <th>Name</th>
#       <th>Age</th>
#       <th>Salary</th>
#       <th>Join_Date</th>
#       <th>Salary_Scaled</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>Rahul</td>
#       <td>25</td>
#       <td>30000</td>
#       <td>2023-01-02</td>
#       <td>-0.339683</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>Anita</td>
#       <td>27</td>
#       <td>35000</td>
#       <td>2023-12-03</td>
#       <td>1.358732</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>Karan</td>
#       <td>24</td>
#       <td>28000</td>
#       <td>2023-01-20</td>
#       <td>-1.019049</td>
#     </tr>
#   </tbody>
# </table>

# %%
data.to_csv("standardized_employee_data.csv", index=False)

# %%
data.head()
html_table = data.to_html(index=False, justify='center')

display(HTML(html_table))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: center;">
#       <th>ID</th>
#       <th>Name</th>
#       <th>Age</th>
#       <th>Salary</th>
#       <th>Join_Date</th>
#       <th>Salary_Scaled</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>Rahul</td>
#       <td>25</td>
#       <td>30000</td>
#       <td>2023-01-02</td>
#       <td>-0.339683</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>Anita</td>
#       <td>27</td>
#       <td>35000</td>
#       <td>2023-12-03</td>
#       <td>1.358732</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>Karan</td>
#       <td>24</td>
#       <td>28000</td>
#       <td>2023-01-20</td>
#       <td>-1.019049</td>
#     </tr>
#   </tbody>
# </table>
